# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/Colab\ Notebooks/storage/CP
# Out:
# /content/drive/.shortcut-targets-by-id/16oN4V1WxH9XSn_ppLcPs96ONB7m6vbc4/CP

# %%
cd ../ParaleloInferedAllOtimizado/
# Out:
# /content/drive/.shortcut-targets-by-id/16oN4V1WxH9XSn_ppLcPs96ONB7m6vbc4/CP/ParaleloInferedAllOtimizado

# %%
# !ls
# Out:
# knn	knn.cuh		   Makefile	 utilsGpu.cu   utilsHost.cpp
# knn.cu	knnSequencial.cpp  runTestes.py  utilsGpu.cuh  utilsHost.hpp

# %%
# !make
# Out:
# nvcc -o knn -O3 knn.cu utilsGpu.cu utilsHost.cpp -I ./
# knn.cu(210): warning #177-D: variable "label" was declared but never referenced
#           int label = labelsTest[i];
#               ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# knn.cu(162): warning #550-D: variable "startMemo" was set but never used
#       clock_t start, end, startMemo, endMemo;
#                           ^
#
# knn.cu(162): warning #550-D: variable "endMemo" was set but never used
#       clock_t start, end, startMemo, endMemo;
#                                      ^

# %%
# !./knn 3 5 5
# Out:
# 137668

# %%
# !nvidia-smi
# Out:
# Sun Jul 14 23:56:02 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8              13W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
! python3 runTestes.py
# Out:
# nvcc -o knn -O3 knn.cu utilsGpu.cu utilsHost.cpp -I ./
# knn.cu(210): warning #177-D: variable "label" was declared but never referenced
#           int label = labelsTest[i];
#               ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# knn.cu(162): warning #550-D: variable "startMemo" was set but never used
#       clock_t start, end, startMemo, endMemo;
#                           ^
#
# knn.cu(162): warning #550-D: variable "endMemo" was set but never used
#       clock_t start, end, startMemo, endMemo;
#                                      ^
#
# Executando: (16, 16) 1
# Execução: 0
# ./knn 1 16 16
# 15234
# Done
# 1 16 16 15234.0
#
# Executando: (16, 16) 3
# Execução: 0
# ./knn 3 16 16
# 15506.8
# Done
# 3 16 16 15506.8
#
# Executando: (16, 16) 5
# Execução: 0
# ./knn 5 16 16
# 15903
# Done
# 5 16 16 15903.0
#
# Executando: (16, 16) 7
# Execução: 0
# ./knn 7 16 16
# 16309.9
# Done
# 7 16 16 16309.9
#
# Executando: (16, 16) 9
# ...
